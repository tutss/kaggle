# %%
# %store -r import_all_libs

# %%
import_all_libs

# %%
df = pd.read_csv('~/datasets/playground-series/train.csv')
df.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12  \
# 0   0    A    I    A    B    B   BI    A    S    Q    A    LO     A     A
# 1   1    A    I    A    A    E   BI    K    W   AD    F    HJ     A     B
# 2   2    A    K    A    A    E   BI    A    E   BM    L    DJ     A     B
# 3   3    A    K    A    C    E   BI    A    Y   AD    F    KV     A     A
# 4   4    A    I    G    B    E   BI    C    G    Q    A    DP     A     A
#
#   cat13 cat14 cat15 cat16 cat17 cat18  cont0  cont1  cont2  cont3  cont4  \
# 0     A     A     B     D     D     B   0.63   0.86   0.76   0.80   0.68
# 1     A     B     D     B     D     B   0.37   0.33   0.39   0.54   0.39
# 2     A     A     B     D     D     B   0.50   0.32   0.34   0.62   0.79
# 3     A     A     B     D     D     B   0.93   0.71   0.83   0.81   0.80
# 4     A     B     B     B     D     B   0.25   0.27   0.34   0.28   0.61
#
#    cont5  cont6  cont7  cont8  cont9  cont10  target
# ...

# %%
df.shape
# Out:
# (300000, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 32 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      300000 non-null  int64
#  1   cat0    300000 non-null  object
#  2   cat1    300000 non-null  object
#  3   cat2    300000 non-null  object
#  4   cat3    300000 non-null  object
#  5   cat4    300000 non-null  object
#  6   cat5    300000 non-null  object
#  7   cat6    300000 non-null  object
#  8   cat7    300000 non-null  object
#  9   cat8    300000 non-null  object
#  10  cat9    300000 non-null  object
#  11  cat10   300000 non-null  object
#  12  cat11   300000 non-null  object
#  13  cat12   300000 non-null  object
#  14  cat13   300000 non-null  object
#  15  cat14   300000 non-null  object
#  16  cat15   300000 non-null  object
#  17  cat16   300000 non-null  object
#  18  cat17   300000 non-null  object
#  19  cat18   300000 non-null  object
# ...

# %%
cat_cols = list()
num_cols = list()
for col in df.columns:
    if df[col].dtype == object:
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
cat_df = df[cat_cols]

# %%
cat_df
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12  \
# 0         A    I    A    B    B   BI    A    S    Q    A    LO     A     A
# 1         A    I    A    A    E   BI    K    W   AD    F    HJ     A     B
# 2         A    K    A    A    E   BI    A    E   BM    L    DJ     A     B
# 3         A    K    A    C    E   BI    A    Y   AD    F    KV     A     A
# 4         A    I    G    B    E   BI    C    G    Q    A    DP     A     A
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 299995    A    N    F    A    E   BU    A   AS    K    A    HG     A     A
# 299996    A    K    A    A    G   BI    A    K   AE    E    HK     A     B
# 299997    A    G    M    A    H   BI    C    L    F    A    HC     B     A
# 299998    B    H    A    D    B   BI    A   AA   AX    A    BF     A     A
# 299999    A    F    C    A    E   BI    C   AV    S    A    LM     A     A
#
#        cat13 cat14 cat15 cat16 cat17 cat18
# ...

# %%
cat_df.describe()
# Out:
#           cat0    cat1    cat2    cat3    cat4    cat5    cat6    cat7  \
# count   300000  300000  300000  300000  300000  300000  300000  300000
# unique       2      15      19      13      20      84      16      51
# top          A       I       A       A       E      BI       A      AH
# freq    223525   90809  168694  187251  129385  238563  187896   45818
#
#           cat8    cat9   cat10   cat11   cat12   cat13   cat14   cat15  \
# count   300000  300000  300000  300000  300000  300000  300000  300000
# unique      61      19     299       2       2       2       2       4
# top         BM       A      DJ       A       A       A       A       B
# freq     42380  201945   31584  258932  257139  292712  160166  203574
#
#          cat16   cat17   cat18
# count   300000  300000  300000
# unique       4       4       4
# top          D       D       B
# freq    206906  247125  255482

# %%
cat_df.describe().iloc[3] / cat_df.shape[0]
# Out:
# cat0    0.75
# cat1    0.30
# cat2    0.56
# cat3    0.62
# cat4    0.43
# cat5    0.80
# cat6    0.63
# cat7    0.15
# cat8    0.14
# cat9    0.67
# cat10   0.11
# cat11   0.86
# cat12   0.86
# cat13   0.98
# cat14   0.53
# cat15   0.68
# cat16   0.69
# cat17   0.82
# cat18   0.85
# Name: freq, dtype: object

# %%
for col in cat_cols:
    xy = cat_df[col].value_counts()
    plt.figure(figsize=(20,5))
    plt.title(f'Column {col}')
    plt.bar(xy.index, height=xy.values)
    plt.show();

# %%
df.isna().sum()
# Out:
# id        0
# cat0      0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
# cat5      0
# cat6      0
# cat7      0
# cat8      0
# cat9      0
# cat10     0
# cat11     0
# cat12     0
# cat13     0
# cat14     0
# cat15     0
# cat16     0
# cat17     0
# cat18     0
# cont0     0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# target    0
# dtype: int64

# %%
df.target.unique()
# Out:
# array([0, 1])

# %%
df.target.value_counts()
# Out:
# 0    220539
# 1     79461
# Name: target, dtype: int64

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
X_train, X_val, y_train, y_val = train_test_split(df.drop(['target'], axis=1), df.target, test_size=0.4)

# %%
rf = RandomForestClassifier(n_estimators=250)

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2a0908a5301f> in <module>
#       1 rf.fit(X_train, y_train)
# ----> 2 y_hat = rf.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
y_hat = rf.predict(X_val)

# %%
roc_auc_score(y_val, y_hat)
# Out:
# 0.7665201193815827
